# %%
from google.colab import files

# %%
Data=files.upload()
# Out:
#      <input type="file" id="files-9d04ef80-92cf-4d33-97ac-6fcf29ba5cbe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d04ef80-92cf-4d33-97ac-6fcf29ba5cbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ls
# Out:
# customers.csv  products.csv  sample_data/  transactions.csv

# %%
import pandas as pd
df=pd.DataFrame
df1=pd.read_csv('customers.csv')
df2=pd.read_csv('products.csv')
df3=pd.read_csv('transactions.csv')

# %%
df1.head()
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive       createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  21-09-2017 12:38
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y  22-05-2017 05:29
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  03-09-2017 12:11
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y  16-02-2017 04:05
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y  15-05-2017 07:34
#
#         UpdatedDate
# 0  18-10-2017 12:12
# 1  18-10-2017 12:12
# 2  18-10-2017 12:12
# 3  18-10-2017 12:12
# 4  18-10-2017 12:12

# %%
df2.head()
# Out:
#    productno productName Description isActive       createdDate  \
# 0          1    Product1  pgqorighfa        Y  03-04-2017 07:58
# 1          2    Product2  lmndaaweth        Y  21-09-2017 12:38
# 2          3    Product3  urifeubrhh        Y  08-09-2017 10:32
# 3          4    Product4  rlpcjxfarp        Y  22-05-2017 05:29
# 4          5    Product5  hzcpozsgfc        Y  02-02-2017 08:40
#
#         UpdatedDate
# 0  18-10-2017 12:12
# 1  18-10-2017 12:12
# 2  18-10-2017 12:12
# 3  18-10-2017 12:12
# 4  18-10-2017 12:12

# %%
df3.head()
# Out:
#    txnno           txndate  custno  amount  productno spendby
# 0      1  18-10-2017 12:31     923    2559        376    Card
# 1      2  18-10-2017 12:31     219    1706        151    Card
# 2      3  18-10-2017 12:31     927    3462        707    Cash
# 3      4  18-10-2017 12:31     806     865        539    Card
# 4      5  18-10-2017 12:31     958    2494         25    Card

# %%
user_case2=pd.merge(df1,df3,how='inner')
x=user_case2.groupby(['custno','firstname'])['productno'].nunique()
x
# Out:
# custno  firstname
# 2       Judy         2
# 3       Marsha       1
# 4       Alexis       4
# 5       Martha       1
# 7       Billy        1
#                     ..
# 991     Catherine    1
# 992     Tamara       3
# 996     Roxanne      1
# 997     Kristen      2
# 999     Betty        1
# Name: productno, Length: 648, dtype: int64

# %%
customers_display=x[x>3]
customers_display
# Out:
# custno  firstname
# 4       Alexis       4
# 86      Bonnie       4
# 167     Alice        4
# 187     Alan         4
# 237     Dawn         4
# 241     Derrick      5
# 321     Crystal      4
# 326     Heidi        4
# 331     Cynthia      4
# 356     Mitchell     4
# 391     Keith        5
# 537     Jake         4
# 558     Lois         4
# 578     Christine    4
# 709     Kyle         4
# 735     James        4
# 753     Denise       4
# 828     Katrina      4
# 989     Ronald       4
# Name: productno, dtype: int64

# %%
user_case3=pd.merge(df2,df3,how='inner')
y=user_case3.groupby('productno')['txnno'].count()
y
# Out:
# productno
# 1      1
# 2      1
# 3      1
# 4      2
# 5      1
#       ..
# 994    1
# 995    3
# 996    1
# 997    1
# 998    2
# Name: txnno, Length: 631, dtype: int64

# %%
demand_product=y.sort_values(ascending=False).head()
demand_product
# Out:
# productno
# 900    5
# 427    5
# 768    5
# 82     5
# 155    4
# Name: txnno, dtype: int64

# %%
user_case4=df3['amount'].head()
user_case4
# Out:
# 0    2559
# 1    1706
# 2    3462
# 3     865
# 4    2494
# Name: amount, dtype: int64

# %%
df1['profession'].unique()
# Out:
# array(['B', 'S'], dtype=object)

# %%
df1['age'].max()
# Out:
# 64

# %%
df7=pd.merge(df1,df3,on='custno',how='inner')
user_case7=pd.merge(df7,df2,on='productno',how='inner')
condition=user_case7[user_case7["custno"]==923]

# %%
print(condition.columns)
# Out:
# Index(['custno', 'firstname', 'lastname', 'gender', 'age', 'profession',
#        'contactNo', 'emailId', 'city', 'state', 'isActive_x', 'createdDate_x',
#        'UpdatedDate_x', 'txnno', 'txndate', 'amount', 'productno', 'spendby',
#        'productName', 'Description', 'isActive_y', 'createdDate_y',
#        'UpdatedDate_y'],
#       dtype='object')

# %%
final_result=condition[['custno','gender','age','profession','contactNo','productno','productName','txndate','spendby','amount']]
final_result
# Out:
#      custno gender  age profession  contactNo  productno productName  \
# 929     923      F   46          B      25436        376  Product376
# 930     923      F   46          B      25436        113  Product113
# 931     923      F   46          B      25436        644  Product644
#
#               txndate spendby  amount
# 929  18-10-2017 12:31    Card    2559
# 930  18-10-2017 12:31    Card    2303
# 931  18-10-2017 12:31    Cash    4553

# %%
from google.colab import files
Data=files.upload()
# Out:
#      <input type="file" id="files-54413e9c-80d4-4a90-b7e1-08b7e5afccb1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54413e9c-80d4-4a90-b7e1-08b7e5afccb1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.DataFrame
df4=pd.read_csv('customers.txt',sep='|')
df5=pd.read_csv('products.txt',sep='|')
df6=pd.read_csv('transactions.txt',sep='|')

# %%
df4.head()
# Out:
#    1   Leslie    Bass  F  27  B  37307      endslost@everyma1l.org   Gibson  \
# 0  2     Judy   Burks  M  53  S  84759      rfleming@hotma1l.co.uk  Suwanee
# 1  3   Marsha   Doyle  F  48  B  80932        arethe53@ma1lbox.net    Perry
# 2  4   Alexis  Battle  M  27  S  71701          ofcame@ma1lbox.org   Morven
# 3  5   Martha   Combs  F  49  B  83947       camedied@everyma1l.us   Ocilla
# 4  6  Marilyn  Nguyen  M  57  S  72274  discoveredlist82@gma1l.org    Byron
#
#     Dellwood  Y  2017-09-21 12:38:22  2017-10-18 12:12:28
# 0     Trabue  Y  2017-05-22 05:29:22  2017-10-18 12:12:28
# 1  Moxadarla  Y  2017-09-03 12:11:29  2017-10-18 12:12:28
# 2     Dennis  Y  2017-02-16 04:05:35  2017-10-18 12:12:28
# 3  Greenwood  Y  2017-05-15 07:34:35  2017-10-18 12:12:28
# 4    Wetsell  Y  2017-05-12 06:18:16  2017-10-18 12:12:28

# %%
df5.head()
# Out:
#    1  Product1  pgqorighfa  Y  2017-04-03 07:58:55  2017-10-18 12:12:38
# 0  2  Product2  lmndaaweth  Y  2017-09-21 12:38:31  2017-10-18 12:12:38
# 1  3  Product3  urifeubrhh  Y  2017-09-08 10:32:12  2017-10-18 12:12:38
# 2  4  Product4  rlpcjxfarp  Y  2017-05-22 05:29:27  2017-10-18 12:12:38
# 3  5  Product5  hzcpozsgfc  Y  2017-02-02 08:40:29  2017-10-18 12:12:38
# 4  6  Product6  ezhxpqxqdg  Y  2017-01-13 12:47:01  2017-10-18 12:12:38

# %%
df6.head()
# Out:
#    1  2017-10-18 12:31:45  923  2559  376  Card
# 0  2  2017-10-18 12:31:45  219  1706  151  Card
# 1  3  2017-10-18 12:31:45  927  3462  707  Cash
# 2  4  2017-10-18 12:31:45  806   865  539  Card
# 3  5  2017-10-18 12:31:45  958  2494   25  Card
# 4  6  2017-10-18 12:31:45   37  3782  603  Cash

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-c9ada16e-2c57-4905-bd58-6a6a227bb70a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9ada16e-2c57-4905-bd58-6a6a227bb70a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.DataFrame
df15=pd.read_xml('customers.xml')
df16=pd.read_xml('products.xml')
df17=pd.read_xml('transactions.xml')

# %%
df15.head()
# Out:
#    custno firstname  lastname  gender  age          profession      contactNo  \
# 0       1    Teegan   Hubbard       2   33     Human Resources  1681121691699
# 1       2    Deacon    Briggs       2   54  Customer Relations  1631082682999
# 2       3   Mallory   Shelton       1   57  Customer Relations  1627011572699
# 3       4     Quinn  Clements       2   43     Media Relations  1618122268999
# 4       5    Arthur     Hurst       2   41        Tech Support  1681021022799
#
#                           emailId             city         state  isActive  \
# 0       nibh.Quisque@placerat.com       Galashiels  Selkirkshire         1
# 1      facilisis.eget@Nullaeu.com  Lens-Saint-Remy            LU         1
# 2    Curabitur.ut@Nullatempor.edu      North Shore            NI         1
# 3  metus.Vivamus.euismod@urna.edu          Heredia             H         1
# 4             in@commodoipsum.org        San Diego       Cartago         2
#
#   createdDate UpdatedDate
# ...

# %%
df16.head()
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100  Hyundai Motors       eight         2  2017-10-01  2017-11-04
# 1        101           Honda       eight         1  2017-04-10  2017-11-11
# 2        102             GMC       three         2  2017-02-09  2017-11-17
# 3        103           Lexus       eight         2  2017-06-01  2017-11-04
# 4        104           Smart        five         2  2017-08-10  2017-11-16

# %%
df17.head()
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-09-16       6     576         73        1
# 1      2  2018-02-11      96    1038         40        2
# 2      3  2017-06-13      17     673          2        1
# 3      4  2017-07-25      89    1284        100        2
# 4      5  2017-06-15       9    1685         56        2

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-2463aef5-0aff-43ee-8766-dee28a87ee37" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2463aef5-0aff-43ee-8766-dee28a87ee37">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df10=pd.read_json('customers.json',lines=True)
df11=pd.read_json('products.json',lines=True)
df13=pd.read_json('transactions.json',lines=True)

# %%
df10
# Out:
#     custno  firstname    lastname  gender  age          profession  \
# 0        1        Dai       Noble       2   53     Human Resources
# 1        2        Kay        Wise       2   26    Public Relations
# 2        3       Amir        Pace       1   43  Customer Relations
# 3        4  Sebastian       Lopez       2   32  Customer Relations
# 4        5      Brian      Maddox       1   40   Quality Assurance
# ..     ...        ...         ...     ...  ...                 ...
# 95      96     Tanner     Webster       1   29          Accounting
# 96      97    Tatiana       Gates       2   54         Advertising
# 97      98     Baxter  Valenzuela       1   43    Asset Management
# 98      99   Chadwick     Mcclure       2   42             Payroll
# 99     100       Tate       Booth       2   53         Advertising
#
#         contactNo                               emailId                 city  \
# 0   1644101928099          eu.lacus.Quisque@loremac.com               Berlin
# ...

# %%
df11.head()
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100        Vauxhall        four         2  2016-11-21  2017-11-09
# 1        101          Toyota         six         2  2017-10-03  2017-11-13
# 2        102  General Motors         two         1  2017-09-18  2017-11-03
# 3        103         Renault       eight         2  2017-10-05  2017-11-13
# 4        104        Kenworth       three         1  2017-05-03  2017-11-04

# %%
df13.head()
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-07-31      71     181         19        2
# 1      2  2017-04-02      44     401         48        2
# 2      3  2018-01-31      45    1808         44        2
# 3      4  2018-04-02      62      65         22        2
# 4      5  2017-08-17      88    1149         74        2
